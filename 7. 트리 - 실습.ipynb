# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

# %%
class NodeMgmt:
    def __init__(self,head):
        self.head = head
    
    def insert(self,value):
        self.current_node = self.head
        while True:
            if value < self.current_node.value:
                if self.current_node.left !=None:
                    self.current_node= self.current_node.left
                else:    
                    self.current_node.left = Node(value)
                    break
            else:
                if self.current_node.right !=None:
                    self.current_node = self.current_node.right
                else:
                    self.current_node.right= Node(value) 
                    break
                    
    def search(self,value):
        self.current_node = self.head
        while self.current_node:
            if self.current_node.value == value:
                return True
            elif value < self.current_node.value:
                self.current_node = self.current_node.left
            else:
                self.current_node = self.current_node.right
        return False

# %%
head = Node(1)
BST = NodeMgmt(head)

# %%
BST.insert(3)
BST.insert(0)
BST.insert(2)
BST.insert(4)
BST.insert(8)

# %%
BST.search(9)
# Out:
# False

# %% [markdown]
# ## 이진 탐색 트리 삭제 코드

# %%
def delete(self, value):
# 삭제할 value가 있는지 확인하고, 없으면 False Return 후 함수 종료
    searched = False
    self.parent = self.head
    self.current_node = self.head
    while self.current_node:
        if self.current_node.value == value:
            searched = True
            break
            
        elif value < self.current_node.value:
            self.parent = self.current_node
            self.current_node= self.current_node.left 
        else:
            self.parent = self.current_node
            self.current_node = self.current_node.right
    
    if searched == False:
        return False

# 이후부터 Case1, Case2, Case3 분리해서 코드 작성

# (1) Case 1 - 가장 마지막 Node (Terminal - Leaf Node)
    if (self.current_node.left == None and self.current_node.right == None):
        if value < self.parent:
            self.parent.left = None
        else:
            self.parent.right = None
        del self.current_node
        
# (2) Case 2 - Child Node가 1개일 때
    if (self.current_node.left != None and self.current_node.right == None):
        if value < self.parent.value:
            self.parent.left = self.current_node.left
        else:
            self.parent.right = self.current_node.left
    elif (self.current_node.right != None and self.current_node.left == None):
        if value < self.parent.value:
            self.parent.left = self.current_node.right
        else:
            self.parent.right = self.current_node.right
        del self.current_node
        
# (3) Case 3 - Child Node가 2개 이상일 때
    if (self.current_node.left != None and self.current_node.right != None):
        if value<self.parent.value:
            self.change_node= self.current_node.right
            self.change_node_parent = self.current_node.right
            while self.change_node.left != None:
                self.change_node_parent = self.change_node
                self.change_node = self.change_node.left
            if self.change_node.right != None:
                self.change_node_parent.left = self.change_node.right
            else:
                self.change_node_parent.left = None
        
            self.parent.left = self.change_node
            self.change_node.right = self.current_node.right
            self.change_node.left = self.current_node.left
        
        else:
            self.change_node = self.current_node.right
            self.change_node_parent = self.current_node.right
            while self.change_node.left != None:
                self.change_node_parent =self.change_node
                self.change_node = self.change_node.left
            if self.change_node.right != None:
                self.change_node_parent.left = self.change_node.right
            else:
                self.change_node_parent.left = None
            
            self.parent.right=self.change_node
            self.change_node.left = self.current_node.left
            self.change_node.right = self.current_node.right

# %% [markdown]
# ## 전체 코드 구현하기

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

# %%
class NodeMgmt:
    def __init__(self,head):
        self.head = head
    
    def insert(self,value):
        self.current_node = self.head
        while True:
            if value < self.current_node.value:
                if self.current_node.left !=None:
                    self.current_node= self.current_node.left
                else:    
                    self.current_node.left = Node(value)
                    break
            else:
                if self.current_node.right !=None:
                    self.current_node = self.current_node.right
                else:
                    self.current_node.right= Node(value) 
                    break
                    
    def search(self,value):
        self.current_node = self.head
        while self.current_node:
            if self.current_node.value == value:
                return True
            elif value < self.current_node.value:
                self.current_node = self.current_node.left
            else:
                self.current_node = self.current_node.right
        return False   
    
    def delete(self, value):
        # 삭제할 value가 있는지 확인하고, 없으면 False Return 후 함수 종료
        searched = False
        self.parent = self.head
        self.current_node = self.head
        
        while self.current_node:
            if self.current_node.value == value:
                searched = True
                break

            elif value < self.current_node.value:
                self.parent = self.current_node
                self.current_node= self.current_node.left 
            else:
                self.parent = self.current_node
                self.current_node = self.current_node.right

        if searched == False:
            return False

        # 이후부터 Case1, Case2, Case3 분리해서 코드 작성

        # (1) Case 1 - 가장 마지막 Node (Terminal - Leaf Node)
        if self.current_node.left == None and self.current_node.right == None:
            if value < self.parent.value:
                self.parent.left = None
            else:
                self.parent.right = None
            del self.current_node

        # (2) Case 2 - Child Node가 1개일 때
        elif self.current_node.left != None and self.current_node.right == None:
            if value < self.parent.value:
                self.parent.left = self.current_node.left
            else:
                self.parent.right = self.current_node.left
        elif (self.current_node.right != None and self.current_node.left == None):
            if value < self.parent.value:
                self.parent.left = self.current_node.right
            else:
                self.parent.right = self.current_node.right
            del self.current_node

        # (3) Case 3 - Child Node가 2개 이상일 때
        elif self.current_node.left != None and self.current_node.right != None:
            if value<self.parent.value:
                self.change_node= self.current_node.right
                self.change_node_parent = self.current_node.right
                while self.change_node.left != None:
                    self.change_node_parent = self.change_node
                    self.change_node = self.change_node.left
                if self.change_node.right != None:
                    self.change_node_parent.left = self.change_node.right
                else:
                    self.change_node_parent.left = None

                self.parent.left = self.change_node
                self.change_node.right = self.current_node.right
                self.change_node.left = self.current_node.left

            else:
                self.change_node = self.current_node.right
                self.change_node_parent = self.current_node.right
                while self.change_node.left != None:
                    self.change_node_parent =self.change_node
                    self.change_node = self.change_node.left
                if self.change_node.right != None:
                    self.change_node_parent.left = self.change_node.right
                else:
                    self.change_node_parent.left = None

                self.parent.right=self.change_node
                self.change_node.left = self.current_node.left
                self.change_node.right = self.current_node.right

# %%
import random

# 1 ~ 999 중 100 개의 숫자
bst_nums = set()
while len(bst_nums) != 100:
    bst_nums.add(random.randint(0,999))

# 선택된 100개의 숫자를 이진 탐색 트리에 입력. 임의로 루트 노드는 500
head = Node(500)
binary_tree = NodeMgmt(head)
for num in bst_nums:
    binary_tree.insert(num)
    
# 입력한 100개의 숫자 검색 (검색 기능)
for num in bst_nums:
    if binary_tree.search(num) == True:
        print('search_success',num)
        
# 입력한 100개의 숫자 중 10개의 숫자를 랜덤 선택
delete_nums = set()
bst_nums = list(bst_nums)
while len(delete_nums) != 10:
    delete_nums.add(bst_nums[random.randint(0,99)])
    
# 선택한 10개의 숫자를 삭제 (삭제 기능)
for del_num in delete_nums:
     print('delete_success',del_num)
    if binary_tree.delete(del_num) == False:
        print('delete_fail',del_num)
        
print(binary_tree.search(606))
# Out:
# search_success 515
# search_success 6
# search_success 520
# search_success 521
# search_success 11
# search_success 524
# search_success 530
# search_success 30
# search_success 32
# search_success 33
# search_success 554
# search_success 560
# search_success 50
# search_success 565
# search_success 568
# search_success 575
# search_success 590
# search_success 620
# search_success 118
# search_success 119
# search_success 129
# search_success 132
# search_success 651
# search_success 653
# search_success 661
# search_success 156
# search_success 668
# search_success 165
# search_success 166
# search_success 167
# search_success 168
# search_success 177
# search_success 184
# search_success 699
# search_success 188
# search_success 700
# search_success 713
# search_success 720
# search_success 210
# search_success 725
# search_success 217
# search_success 228
# search_success 747
# search_success 749
# search_success 754
# search_success 244
# search_success 759
# search_success 249
# search_success 251
# search_success 259
# search_success 774
# search_success 279
# search_success 287
# search_success 293
# search_success 813
# search_success 305
# search_success 818
# search_success 824
# search_success 323
# search_success 325
# search_success 839
# search_success 842
# search_success 844
# search_success 333
# search_success 845
# search_success 852
# search_success 857
# search_success 866
# search_success 354
# search_success 876
# search_success 374
# search_success 375
# search_success 377
# search_success 893
# search_success 382
# search_success 896
# search_success 386
# search_success 387
# search_success 904
# search_success 393
# search_success 402
# search_success 916
# search_success 405
# search_success 409
# search_success 924
# search_success 927
# search_success 936
# search_success 424
# search_success 949
# search_success 951
# search_success 449
# search_success 961
# search_success 971
# search_success 978
# search_success 980
# search_success 471
# search_success 477
# search_success 992
# search_success 994
# search_success 489
# delete_success 33
# delete_success 259
# delete_success 6
# delete_success 393
# delete_success 842
# delete_success 651
# delete_success 524
# delete_success 560
# delete_success 471
# delete_success 217
# False

# %%
bst_nums
# Out:
# set
